# %% [markdown]
# <a href="https://colab.research.google.com/github/Kedree/DataAnalysisUMF/blob/main/HW2/HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW2
#
# Below is the instructions and work for hw2, it is done exclusively in R but the code snippits and results are done in this ipynb so it looks nice!
#
# ### 1.
#
# *Run the following lines and study how they work. Then state what they do and output for us. (20 Points)*
#
# ```
# > df1=data.frame(
# Name=c('James','Paul','Richards','Marico','Samantha','Ravi','Raghu', 'Richards','George','Ema','Samantha','Catherine'),
# State=c('Alaska','California','Texas','North Carolina','California','Texas', 'Alaska','Texas','North Carolina','Alaska','California','Texas'),
# Sales=c(14,24,31,12,13,7,9,31,18,16,18,14))
# ```
# ```
# > head(df1)
#       Name          State Sales
# 1    James         Alaska    14
# 2     Paul     California    24
# 3 Richards          Texas    31
# 4   Marico North Carolina    12
# 5 Samantha     California    13
# 6     Ravi          Texas     7
# ```
# Creates a data frame with columns: Name, State, and Sales. Each person mades sales in their respective state.
#
# ```
# > aggregate(df1$Sales, by=list(df1$State), FUN=sum)
#          Group.1  x
# 1         Alaska 39
# 2     California 55
# 3 North Carolina 30
# 4          Texas 83
# ```
# Sums the total sales for each state and makes a dataframe for it.
#
# ```
# > library(dplyr)
# ```
# Loads the dplyr package.
#
# ```
# > df1 %>% group_by(State) %>% summarise(sum_sales = sum(Sales))
# # A tibble: 4 × 2
#   State          sum_sales
#   <chr>              <dbl>
# 1 Alaska                39
# 2 California            55
# 3 North Carolina        30
# 4 Texas                 83
# ```
# Essentially does the same as the aggregate function only nicer.
#
# ### 2.
# *Use R to read the WorldCupMatches.csv from the DATA folder on Google Drive. Then perform the followings (48
# points):*
#
# ```
# > matches <- read.csv("WorldCupMatches.csv")
# > head(matches)
# Year             Datetime   Stage        Stadium        City
# 1 1930 13 Jul 1930 - 15:00  Group 1        Pocitos Montevideo
# 2 1930 13 Jul 1930 - 15:00  Group 4 Parque Central Montevideo
# 3 1930 14 Jul 1930 - 12:45  Group 2 Parque Central Montevideo
# 4 1930 14 Jul 1930 - 14:50  Group 3        Pocitos Montevideo
# 5 1930 15 Jul 1930 - 16:00  Group 1 Parque Central Montevideo
# 6 1930 16 Jul 1930 - 14:45  Group 1 Parque Central Montevideo
#   Home.Team.Name Home.Team.Goals Away.Team.Goals Away.Team.Name
# 1         France               4               1         Mexico
# 2            USA               3               0        Belgium
# 3     Yugoslavia               2               1         Brazil
# 4        Romania               3               1           Peru
# 5      Argentina               1               0         France
# 6          Chile               3               0         Mexico
#   Win.conditions Attendance Half.time.Home.Goals Half.time.Away.Goals
# 1                      4444                    3                    0
# 2                     18346                    2                    0
# 3                     24059                    2                    0
# 4                      2549                    1                    0
# 5                     23409                    0                    0
# 6                      9249                    1                    0
#                  Referee              Assistant.1
# 1 LOMBARDI Domingo (URU)    CRISTOPHE Henry (BEL)
# 2      MACIAS Jose (ARG) MATEUCCI Francisco (URU)
# 3    TEJADA Anibal (URU)  VALLARINO Ricardo (URU)
# 4  WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)
# 5    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)
# 6  CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)
#                  Assistant.2 RoundID MatchID Home.Team.Initials
# 1        REGO Gilberto (BRA)     201    1096                FRA
# 2      WARNKEN Alberto (CHI)     201    1090                USA
# 3        BALWAY Thomas (FRA)     201    1093                YUG
# 4   MATEUCCI Francisco (URU)     201    1098                ROU
# 5 RADULESCU Constantin (ROU)     201    1085                ARG
# 6        LANGENUS Jean (BEL)     201    1095                CHI
#   Away.Team.Initials
# 1                MEX
# 2                BEL
# 3                BRA
# 4                PER
# 5                FRA
# 6                MEX
# ```
#
# ### (a)
# *Find the size of the data frame. How many rows, how many columns?*
# ```
# > nrow(matches)
# [1] 852
# > ncol(matches)
# [1] 20
# ```
# There are 852 rows and 20 columns
#
# ### (b)
#
# *Use summary function to report the statistical summary of your data.*
#
# ```
# > summary(matches)
#       Year        Datetime            Stage             Stadium              City
#  Min.   :1930   Length:852         Length:852         Length:852         Length:852
#  1st Qu.:1970   Class :character   Class :character   Class :character   Class :character
#  Median :1990   Mode  :character   Mode  :character   Mode  :character   Mode  :character
#  Mean   :1985
#  3rd Qu.:2002
#  Max.   :2014
#
#  Home.Team.Name     Home.Team.Goals  Away.Team.Goals Away.Team.Name     Win.conditions
#  Length:852         Min.   : 0.000   Min.   :0.000   Length:852         Length:852
#  Class :character   1st Qu.: 1.000   1st Qu.:0.000   Class :character   Class :character
#  Mode  :character   Median : 2.000   Median :1.000   Mode  :character   Mode  :character
#                     Mean   : 1.811   Mean   :1.022
#                     3rd Qu.: 3.000   3rd Qu.:2.000
#                     Max.   :10.000   Max.   :7.000
#
#    Attendance     Half.time.Home.Goals Half.time.Away.Goals   Referee          Assistant.1
#  Min.   :  2000   Min.   :0.0000       Min.   :0.0000       Length:852         Length:852
#  1st Qu.: 30000   1st Qu.:0.0000       1st Qu.:0.0000       Class :character   Class :character
#  Median : 41580   Median :0.0000       Median :0.0000       Mode  :character   Mode  :character
#  Mean   : 45165   Mean   :0.7089       Mean   :0.4284
#  3rd Qu.: 61375   3rd Qu.:1.0000       3rd Qu.:1.0000
#  Max.   :173850   Max.   :6.0000       Max.   :5.0000
#  NA's   :2
#  Assistant.2           RoundID            MatchID          Home.Team.Initials Away.Team.Initials
#  Length:852         Min.   :     201   Min.   :       25   Length:852         Length:852
#  Class :character   1st Qu.:     262   1st Qu.:     1189   Class :character   Class :character
#  Mode  :character   Median :     337   Median :     2191   Mode  :character   Mode  :character
#                     Mean   :10661773   Mean   : 61346868
#                     3rd Qu.:  249722   3rd Qu.: 43950059
#                     Max.   :97410600   Max.   :300186515
# ```
# Interesting to note here is that the average home team goals is significantly higher than away team!
#
# ### (c)
# *Find how many unique locations olympics were held at.*
#
# ```
# > length(unique(matches$City))
# [1] 151
# ```
# There were 151 unique cities that the Olympic Games were held in.
#
# ### (d)
# *Find the average attendance.*
#
# ```
# > mean(matches$Attendance, na.rm=TRUE)
# [1] 45164.8
# ```
# The average attendance was 45,164.8, perhaps some of the attendees were missing arms or legs! /s
#
# ### (e)
# *For each Home Team, what is the total number of goals scored? (Hint: Please refer to question 1)*
#
# ```
# > matches %>% group_by(Home.Team.Name) %>% summarise(sum_home_goals = sum(Home.Team.Goals))
# # A tibble: 78 × 2
#    Home.Team.Name sum_home_goals
#    <chr>                   <int>
#  1 Algeria                     5
#  2 Angola                      0
#  3 Argentina                 111
#  4 Australia                   7
#  5 Austria                    31
#  6 Belgium                    27
#  7 Bolivia                     1
#  8 Brazil                    180
#  9 Bulgaria                   11
# 10 Cameroon                   11
# # … with 68 more rows
# ```
# The entire dataframe exists but was cutoff, poor Angola!
#
# ### (f)
# *What is the average number of attendees for each year? Is there a trend or pattern in the data in that sense?*
# ```
# > matches %>% group_by(Year) %>% summarise(avg_attendance = mean(Attendance, na.rm=TRUE))
# # A tibble: 20 × 2
#     Year avg_attendance
#    <int>          <dbl>
#  1  1930         32808.
#  2  1934         21353.
#  3  1938         20872.
#  4  1950         47511.
#  5  1954         29562.
#  6  1958         23423.
#  7  1962         27912.
#  8  1966         48848.
#  9  1970         50124.
# 10  1974         49099.
# 11  1978         40679.
# 12  1982         40572.
# 13  1986         46039.
# 14  1990         48389.
# 15  1994         68991.
# 16  1998         43517.
# 17  2002         42269.
# 18  2006         52491.
# 19  2010         49670.
# 20  2014         55375.
# ```
# Attendance seems to have increased over time. There are notable outliers that show increased importance of the games on certain years probably due to international politics.
#
# ### 3.
# *Use R to read the metabolites.csv from the DATA folder on Google Drive. Then perform the followings (32 points):*
# ```
# > meta <- read.csv("metabolite.csv")
# > head(meta)
#       Label  Phe Pro Ser Thr ADMA alpha.AAA c4.OH.Pro Carnosine Creatinine  DOPA Dopamine Histamine
# 1 Alzheimer 72.8 166 170 282 1.15     0.760     0.236     1.270       49.9 0.265    0.233     0.225
# 2 Alzheimer 93.4 138 142 217 1.05     0.929     0.189     1.350       48.8 0.252       NA     0.211
# 3 Alzheimer 68.6 161 158 208 1.00     0.620     0.198     0.998       30.4 0.268       NA     0.217
# 4 Alzheimer 94.1 129 162 201 1.10     0.795        NA     0.675       80.1 0.264    0.234     0.209
# 5 Alzheimer 79.8 126 115 199 1.24     1.360        NA     1.280       60.5 0.271    0.231     0.210
#   Kynurenine Met.SO Nitro.Tyr PEA Putrescine Sarcosine Serotonin Spermidine Spermine t4.OH.Pro Taurine
# 1       5.21  0.526     0.027  NA      0.068      17.8     0.147      0.188       NA      24.0     125
# 2       5.44  0.387        NA  NA      0.087      20.2     0.231      0.233       NA      29.3     120
# 3       5.20  0.651        NA  NA      0.260      14.4     0.196      0.384       NA      20.9     139
# 4       5.80  0.389        NA  NA      0.110      18.7     0.255      0.353       NA      23.1     159
# 5       4.46  0.466        NA  NA      0.118      22.5     0.390      0.473       NA      26.9     149
#   SDMA   C0   C10 C10.1 C10.2   C12 C12.DC C12.1   C14 C14.1 C14.1.OH C14.2 C14.2.OH   C16 C16.OH C16.1
# 1 1.13 18.2 0.059 0.312 0.038 0.030  0.042 0.290 0.023 0.019    0.008 0.008    0.006 0.046  0.008 0.009
# 2 1.65 17.0 0.051 0.288 0.039 0.038  0.038 0.265 0.026 0.017    0.008 0.009    0.009 0.070  0.009 0.013
# 3 1.57 12.6 0.083 0.357 0.054 0.032  0.048 0.302 0.021 0.031    0.010 0.010    0.009 0.076  0.011 0.019
# 4 1.34 23.5 0.071 0.317 0.040 0.045  0.048 0.275 0.026 0.028    0.010 0.013    0.011 0.074  0.011 0.015
# 5 1.24 13.6 0.139 0.472 0.074 0.056  0.079 0.394 0.034 0.043    0.016 0.025    0.017 0.062     NA 0.024
#   C16.1.OH C16.2 C16.2.OH   C18 C18.1 C18.1.OH C18.2   C2    C3 C3.OH  C3.1    C4 C3.DC..C4.OH.  C4.1
# 1    0.007 0.005    0.013 0.013 0.024    0.003 0.016 1.97 0.354 0.008 0.015 0.082         0.045 0.025
# 2    0.006 0.006    0.012 0.014 0.025    0.003 0.028 1.95 0.184 0.009 0.013 0.108         0.080 0.025
# 3    0.010 0.005    0.013 0.016 0.025       NA 0.018 1.70 0.371    NA 0.012 0.057         0.035 0.039
# 4    0.008 0.006    0.009 0.020 0.035    0.004 0.033 2.10 0.278 0.010 0.017 0.110         0.077 0.031
# 5    0.014 0.012    0.025 0.031 0.034    0.012 0.017 5.62 0.436 0.029 0.035 0.106         0.099 0.069
#      C5 C5.M.DC C5.OH..C3.DC.M.  C5.1 C5.1.DC C6..C4.1.DC. C5.DC..C6.OH.  C6.1 C7.DC    C8    C9
# 1 0.094   0.023           0.026 0.030   0.020        0.022         0.014 0.018 0.011 0.062 0.016
# 2 0.077   0.032           0.026 0.024   0.021        0.030         0.018 0.015 0.010 0.058 0.014
# 3 0.096   0.045           0.024 0.037   0.018        0.022         0.029 0.031 0.021 0.090 0.017
# 4 0.145   0.034           0.041 0.035   0.016        0.029         0.016 0.027 0.017 0.091 0.018
# 5 0.141   0.094           0.058 0.073   0.049        0.052         0.040 0.040 0.036 0.192 0.041
#   lysoPC.a.C14.0 lysoPC.a.C16.0 lysoPC.a.C16.1 lysoPC.a.C17.0 lysoPC.a.C18.0 lysoPC.a.C18.1
# 1           2.23           37.9           2.66          0.446           9.00           8.58
# 2           1.97           22.1           1.31          0.270           5.35           3.94
# 3           2.12           33.7           2.53          0.399           7.51           7.73
# 4           2.19           32.8           2.39          0.323           7.21           7.22
# 5           1.88           24.5           1.27          0.382           6.66           5.39
#   lysoPC.a.C18.2 lysoPC.a.C20.3 lysoPC.a.C20.4 lysoPC.a.C24.0 lysoPC.a.C26.0 lysoPC.a.C26.1
# 1           7.27          1.830           8.25          0.079          0.113          0.053
# 2           4.42          0.958           4.60          0.059          0.066          0.042
# 3           8.02          2.050           9.84          0.075          0.126          0.049
# 4           7.62          1.640           6.75          0.066          0.086          0.045
# 5           3.60          0.970           6.26          0.084          0.118          0.053
#   lysoPC.a.C28.0 lysoPC.a.C28.1 PC.aa.C24.0 PC.aa.C26.0 PC.aa.C28.1 PC.aa.C30.0 PC.aa.C32.0 PC.aa.C32.1
# 1          0.108          0.072       0.082       0.438       0.571        2.35        11.4        9.22
# 2          0.076          0.058       0.065       0.409       0.521        1.99        12.7        5.40
# 3          0.078          0.092       0.099       0.458       0.605        2.69        16.6       11.60
# 4          0.076          0.076       0.076       0.486       0.685        3.33        18.6       13.30
# 5          0.092          0.072       0.069       0.401       0.513        1.78        13.8        5.03
#   PC.aa.C32.2 PC.aa.C32.3 PC.aa.C34.1 PC.aa.C34.2 PC.aa.C34.3 PC.aa.C34.4 PC.aa.C36.0 PC.aa.C36.1
# 1          NA       0.092       109.0        71.0       1.430       0.200        2.38        21.7
# 2          NA       0.067        64.2        60.5       0.879       0.127        2.05        14.3
# 3          NA       0.105       108.0        83.1       1.930       0.210        2.30        19.9
# 4       0.053       0.079       106.0        93.6       1.590       0.190        2.57        20.9
# 5          NA       0.102        83.4        35.9       0.709       0.135        1.83        20.5
#   PC.aa.C36.2 PC.aa.C36.3 PC.aa.C36.4 PC.aa.C36.5 PC.aa.C36.6 PC.aa.C38.0 PC.aa.C38.3 PC.aa.C38.4
# 1        42.4        42.7       120.0        1.86       0.084       1.230        32.1        95.1
# 2        35.6        24.3        83.7        1.05       0.046       0.946        21.9        78.9
# 3        44.9        43.9       146.0        2.09       0.057       1.210        34.5       107.0
# 4        48.8        41.2       122.0        1.76       0.070       1.160        28.7        92.7
# 5        28.5        21.9        98.1        1.70       0.048       1.100        23.3       101.0
#   PC.aa.C38.5 PC.aa.C38.6 PC.aa.C40.1 PC.aa.C40.2 PC.aa.C40.3 PC.aa.C40.4 PC.aa.C40.5 PC.aa.C40.6
# 1       16.80        41.6       0.195       0.074       0.491        3.48        5.66        21.8
# 2        9.91        25.1       0.211       0.057       0.358        3.39        4.08        14.2
# 3       17.50        36.6       0.212       0.118       0.395        3.56        5.34        16.7
# 4       14.30        29.9       0.220       0.097       0.433        3.59        5.06        14.0
# 5       13.80        36.2       0.165       0.044       0.525        3.37        5.29        22.5
#   PC.aa.C42.0 PC.aa.C42.1 PC.aa.C42.2 PC.aa.C42.4 PC.aa.C42.5 PC.aa.C42.6 PC.ae.C30.0 PC.ae.C30.1
# 1       0.364       0.226       0.108       0.272       0.272       0.291       0.173       0.027
# 2       0.419       0.216       0.109       0.336       0.317       0.248       0.147       0.024
# 3       0.476       0.281       0.118       0.300       0.206       0.267       0.209       0.046
# 4       0.427       0.223       0.119       0.268       0.267       0.254       0.223       0.049
# 5       0.125       0.095       0.083       0.206       0.205       0.280       0.095       0.082
#   PC.ae.C30.2 PC.ae.C32.1 PC.ae.C32.2 PC.ae.C34.0 PC.ae.C34.1 PC.ae.C34.2 PC.ae.C34.3 PC.ae.C36.0
# 1       0.022        1.65       0.371       0.880        3.66        2.48       0.813       0.498
# 2       0.020        2.01       0.360       0.763        2.68        2.32       0.905       0.398
# 3       0.030        2.40       0.477       0.938        4.04        2.95       1.030       0.554
# 4       0.023        2.47       0.459       0.964        4.06        3.09       1.020       0.552
# 5       0.023        1.72       0.316       1.060        3.28        1.70       0.722       0.553
#   PC.ae.C36.1 PC.ae.C36.2 PC.ae.C36.3 PC.ae.C36.4 PC.ae.C36.5 PC.ae.C38.0 PC.ae.C38.1 PC.ae.C38.2
# 1        5.64        1.90       1.170        6.96        4.79       0.474       0.287       0.538
# 2        3.89        1.54       0.873        6.40        5.36       0.325          NA       0.127
# 3        5.95        2.29       1.240        9.05        6.63       0.478       0.285       0.154
# 4        4.75        2.01       1.350        8.36        5.97       0.397       0.022       0.144
# 5        5.95        1.47       0.760        4.78        4.00       0.430       0.271       0.246
#   PC.ae.C38.3 PC.ae.C38.4 PC.ae.C38.5 PC.ae.C38.6 PC.ae.C40.1 PC.ae.C40.2 PC.ae.C40.3 PC.ae.C40.4
# 1        2.66        6.33        5.51        1.95       0.574       0.575       0.940        1.76
# 2        1.80        5.37        4.49        1.63       0.281       0.491       0.702        1.43
# 3        2.87        7.06        5.64        1.98       0.759       0.654       0.817        1.51
# 4        1.97        5.99        5.63        1.97       0.425       0.540       0.742        1.45
# 5        1.80        5.45        4.34        1.51       0.430       0.432       0.632        1.10
#   PC.ae.C40.5 PC.ae.C40.6 PC.ae.C42.0 PC.ae.C42.1 PC.ae.C42.2 PC.ae.C42.3 PC.ae.C42.4 PC.ae.C42.5
# 1        1.77        1.59       0.629       0.316       0.192       0.277       0.264       0.888
# 2        1.55        1.20       0.616       0.260       0.157       0.200       0.311       0.840
# 3        1.64        1.49       0.686       0.356       0.241       0.288       0.319       0.957
# 4        1.62        1.25       0.637       0.299       0.159       0.208       0.392       0.863
# 5        1.25        1.47       0.660       0.355       0.138       0.174       0.162       0.513
#   PC.ae.C44.3 PC.ae.C44.4 PC.ae.C44.5 PC.ae.C44.6 SM..OH..C14.1 SM..OH..C16.1 SM..OH..C22.1
# 1       0.065       0.168       0.536       0.494         1.420          1.33          2.07
# 2       0.071       0.220       0.470       0.515         1.390          1.25          2.47
# 3       0.065       0.228       0.565       0.603         1.840          1.58          2.69
# 4       0.069       0.237       0.517       0.611         1.720          1.48          2.97
# 5       0.081       0.154       0.178       0.134         0.987          1.48          1.96
#   SM..OH..C22.2 SM..OH..C24.1 SM.C16.0 SM.C16.1 SM.C18.0 SM.C18.1 SM.C20.2 SM.C24.0 SM.C24.1 SM.C26.0
# 1          1.86         0.597     44.9     7.99     14.5    10.40    0.290    12.20     27.3    0.147
# 2          2.20         0.640     42.1     6.88     12.7     8.52    0.211    10.40     25.6    0.130
# 3          2.63         0.665     44.8     8.91     14.6    11.60    0.304    11.50     28.8    0.163
# 4          2.84         0.682     52.4     8.61     17.2    11.50    0.261    11.80     27.9    0.138
# 5          1.74         0.478     40.6     5.86     13.0     8.34    0.196     9.29     20.5    0.111
#   SM.C26.1 H1_1   H1 Urea_N L.Arginine_N L.Leucine_N EDTAca_N X2.Hydroxybutyrate X3.Hydroxybutyrate
# 1    0.337 3356 3356     NA           NA          NA       NA                 NA                 NA
# 2    0.317 2509 2509  201.9         22.5        35.3      2.0              12.40                8.5
# 3    0.364 2661 2661  193.3         21.0        25.4      1.8              11.33               11.7
# 4    0.353 2652 2652  500.8         16.0        27.1      2.5              12.70                7.2
# 5    0.283 2258 2258  132.5         13.2        57.9      2.5              35.20               44.7
#   Acetate Acetoacetate Acetone Betaine Carnitine Choline Creatine Dimethyl.sulfone Ethanol Formate
# 1      NA           NA      NA      NA        NA      NA       NA               NA      NA      NA
# 2    13.2          5.7     5.1    22.0       8.7    14.2     14.5              4.7    16.6    24.6
# 3     5.8          9.3     5.6    19.1      15.3    14.5     17.8              2.1     8.1    27.4
# 4     9.8          4.8     4.0    13.9       7.7    11.8     14.7              1.3     6.4    14.4
# 5    20.2         18.9    18.9    33.9      18.5    27.7     35.4              5.5    13.0    40.0
#   Glucose Glycerol Hypoxanthine Isobutyrate Isopropanol Lactate Malonate
# 1      NA       NA           NA          NA          NA      NA       NA
# 2  1489.7    324.6          6.3         3.6         1.9  1171.6     10.4
# 3  1343.9    201.3          6.0         2.5         2.5  1938.1     13.1
# 4   629.5    322.0          8.6         2.5         4.4  1037.7      7.6
# 5  1618.0    271.6          0.0         6.1        11.2  2199.9     11.7
#  [ reached 'max' / getOption("max.print") -- omitted 1 rows ]
# ```
# ### (a)
# *Find how many Alzheimers patients there are in the data set. (Hint: Please refer to question 1)*
# ```
# > meta %>% count(Label)
#       Label  n
# 1 Alzheimer 35
# 2   Healthy 34
# ```
# There are 35 Alzheimers datapoints
# ### (b)
# *Determine the number of missing values for each column. (Hint: is.na( ) )*
# ```
# > sapply(meta, function(x) sum(is.na(x)))
#              Label                Phe                Pro                Ser                Thr
#                  0                  0                  0                  0                  0
#               ADMA          alpha.AAA          c4.OH.Pro          Carnosine         Creatinine
#                  0                  0                 20                  1                  0
#               DOPA           Dopamine          Histamine         Kynurenine             Met.SO
#                  0                 20                  0                  0                  1
#          Nitro.Tyr                PEA         Putrescine          Sarcosine          Serotonin
#                 62                 69                  0                  0                  0
#         Spermidine           Spermine          t4.OH.Pro            Taurine               SDMA
#                  0                 60                  0                  2                  0
#                 C0                C10              C10.1              C10.2                C12
#                  0                  0                  0                  0                  0
#             C12.DC              C12.1                C14              C14.1           C14.1.OH
#                  1                  0                  0                  0                  1
#              C14.2           C14.2.OH                C16             C16.OH              C16.1
#                  0                  2                  0                  1                  0
#           C16.1.OH              C16.2           C16.2.OH                C18              C18.1
#                  2                  2                  1                  0                  0
#           C18.1.OH              C18.2                 C2                 C3              C3.OH
#                  7                  0                  0                  0                  8
#               C3.1                 C4      C3.DC..C4.OH.               C4.1                 C5
#                  2                  0                  0                  0                  0
#            C5.M.DC    C5.OH..C3.DC.M.               C5.1            C5.1.DC       C6..C4.1.DC.
#                  1                  0                  5                  2                  0
#      C5.DC..C6.OH.               C6.1              C7.DC                 C8                 C9
#                  4                  2                  1                  0                  1
#     lysoPC.a.C14.0     lysoPC.a.C16.0     lysoPC.a.C16.1     lysoPC.a.C17.0     lysoPC.a.C18.0
#                  0                  0                  0                  0                  0
#     lysoPC.a.C18.1     lysoPC.a.C18.2     lysoPC.a.C20.3     lysoPC.a.C20.4     lysoPC.a.C24.0
#                  0                  0                  0                  0                  0
#     lysoPC.a.C26.0     lysoPC.a.C26.1     lysoPC.a.C28.0     lysoPC.a.C28.1        PC.aa.C24.0
#                  0                  0                  0                  0                  0
#        PC.aa.C26.0        PC.aa.C28.1        PC.aa.C30.0        PC.aa.C32.0        PC.aa.C32.1
#                  0                  0                  0                  0                  0
#        PC.aa.C32.2        PC.aa.C32.3        PC.aa.C34.1        PC.aa.C34.2        PC.aa.C34.3
#                 47                  0                  0                  0                  0
#        PC.aa.C34.4        PC.aa.C36.0        PC.aa.C36.1        PC.aa.C36.2        PC.aa.C36.3
#                  0                  0                  0                  0                  0
#        PC.aa.C36.4        PC.aa.C36.5        PC.aa.C36.6        PC.aa.C38.0        PC.aa.C38.3
#                  0                  0                  0                  0                  0
#        PC.aa.C38.4        PC.aa.C38.5        PC.aa.C38.6        PC.aa.C40.1        PC.aa.C40.2
#                  0                  0                  0                  0                  0
#        PC.aa.C40.3        PC.aa.C40.4        PC.aa.C40.5        PC.aa.C40.6        PC.aa.C42.0
#                  0                  0                  0                  0                  0
#        PC.aa.C42.1        PC.aa.C42.2        PC.aa.C42.4        PC.aa.C42.5        PC.aa.C42.6
#                  0                  0                  0                  0                  0
#        PC.ae.C30.0        PC.ae.C30.1        PC.ae.C30.2        PC.ae.C32.1        PC.ae.C32.2
#                  0                 10                  0                  0                  0
#        PC.ae.C34.0        PC.ae.C34.1        PC.ae.C34.2        PC.ae.C34.3        PC.ae.C36.0
#                  0                  0                  0                  0                  0
#        PC.ae.C36.1        PC.ae.C36.2        PC.ae.C36.3        PC.ae.C36.4        PC.ae.C36.5
#                  0                  0                  0                  0                  0
#        PC.ae.C38.0        PC.ae.C38.1        PC.ae.C38.2        PC.ae.C38.3        PC.ae.C38.4
#                  0                 52                 19                  0                  0
#        PC.ae.C38.5        PC.ae.C38.6        PC.ae.C40.1        PC.ae.C40.2        PC.ae.C40.3
#                  0                  0                  0                  0                  0
#        PC.ae.C40.4        PC.ae.C40.5        PC.ae.C40.6        PC.ae.C42.0        PC.ae.C42.1
#                  0                  0                  0                  0                  0
#        PC.ae.C42.2        PC.ae.C42.3        PC.ae.C42.4        PC.ae.C42.5        PC.ae.C44.3
#                  1                  0                  0                  0                  0
#        PC.ae.C44.4        PC.ae.C44.5        PC.ae.C44.6      SM..OH..C14.1      SM..OH..C16.1
#                  0                  0                  0                  0                  0
#      SM..OH..C22.1      SM..OH..C22.2      SM..OH..C24.1           SM.C16.0           SM.C16.1
#                  0                  0                  0                  0                  0
#           SM.C18.0           SM.C18.1           SM.C20.2           SM.C24.0           SM.C24.1
#                  0                  0                  0                  0                  0
#           SM.C26.0           SM.C26.1               H1_1                 H1             Urea_N
#                  0                  0                  0                  0                  1
#       L.Arginine_N        L.Leucine_N           EDTAca_N X2.Hydroxybutyrate X3.Hydroxybutyrate
#                  1                  1                  1                  1                  1
#            Acetate       Acetoacetate            Acetone            Betaine          Carnitine
#                  1                  1                  1                  1                  1
#            Choline           Creatine   Dimethyl.sulfone            Ethanol            Formate
#                  1                  1                  1                  2                  2
#            Glucose           Glycerol       Hypoxanthine        Isobutyrate        Isopropanol
#                  1                  1                  1                  1                  1
#            Lactate           Malonate
#                  1                  1
# ```
# Wow! A lot to look at, lots of missing for c4.HO.Pro, PEA, Spermine, Nitro.tyr, etc.
# ### (c)
# *Remove the rows which has missing value for the Dopamine column and assign the result to a new data frame. (Hint: is.na( ) )*
# ```
# > meta_no_fun = meta[is.na(meta$Dopamine), ]
# > meta_no_fun$Dopamine
#  [1] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
# > meta = meta[!is.na(meta$Dopamine), ]
# > meta$Dopamine
#  [1] 0.233 0.234 0.231 0.244 0.233 0.225 0.240 0.239 0.231 0.236 0.235 0.233 0.234 0.228 0.229 0.227
# [17] 0.231 0.227 0.226 0.235 0.236 0.225 0.231 0.229 0.232 0.240 0.235 0.229 0.235 0.229 0.224 0.256
# [33] 0.228 0.231 0.237 0.236 0.225 0.236 0.235 0.231 0.230 0.230 0.234 0.231 0.228 0.230 0.230 0.248
# [49] 0.234
# ```
# The newly-made dataframes function as expected and are of correct dimensions according to R browser
#
# ### (d)
# *In the new data frame, replace the missing values in the c4-OH-Pro column with the median value of the same column. (Hint: there is median( ) function.)*
# ```
# > meta_no_fun$c4.OH.Pro[is.na(meta_no_fun$c4.OH.Pro)]<-median(meta_no_fun$c4.OH.Pro, na.rm=TRUE)
# > median(meta_no_fun$c4.OH.Pro, na.rm=TRUE)
# [1] 0.197
# > meta_no_fun$c4.OH.Pro
#  [1] 0.189 0.198 0.197 0.184 0.237 0.197 0.197 0.202 0.299 0.244 0.195 0.197 0.182 0.186 0.363 0.197
# [17] 0.189 0.184 0.197 0.250
# ```
# The code worked correctly and all of the NA spots are filled in with median value of 0.197, is fabricating medical data illegal?! /s
#
# ### (e)
# *__(Optional)__ Drop columns which have more than 25% missing values. (Hint: when you slice your data frame, you can use -c(.., ..., ...) where ... represent one column name)*
# ```
# > ncol(meta_no_fun)
# [1] 192
# > meta_no_funCleaned = meta_no_fun[, which(colMeans(!is.na(meta_no_fun)) >= .25)]
# > ncol(meta_no_funCleaned)
# [1] 187
# ```
# A quick cursory glance over the data shows that it seems to have worked, and definetly worked for columns like dopamine and Nitro.tyr / PEA. I DID IT! probably not the exact way expected but it worked! 🎉
